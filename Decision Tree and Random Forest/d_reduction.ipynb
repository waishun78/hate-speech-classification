# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from sklearn.decomposition import PCA

# %% [markdown]
# ### Data retrieval

# %%
df = pd.read_csv("../Training and Testing sets/train_tfidf_features.csv")

# %% [markdown]
# ### Reducing the dimensions

# %%
label = df.loc[:,["label"]]
features_names = [str(i) for i in range(0,5000)]
features = df.loc[:,features_names]

# %% [markdown]
# ##### 2000 features

# %%
pca2000 = PCA(n_components=2000)
principalComponents2000 = pca2000.fit_transform(features)
principalDf2000 = pd.DataFrame(data = principalComponents2000)
principalDf2000
# Out:
#            0         1         2         3         4         5         6     \
# 0     -0.083198 -0.016048 -0.010595 -0.001965 -0.013779 -0.010989 -0.009680
# 1     -0.068421 -0.043649 -0.018443 -0.008228 -0.000051 -0.043177  0.127322
# 2     -0.080171 -0.044642 -0.015342 -0.008697 -0.010481 -0.057562  0.075615
# 3      0.028600 -0.040406  0.002784  0.007087  0.000462 -0.031219 -0.137444
# 4      0.255054 -0.113418 -0.019237 -0.021468 -0.040033 -0.007000 -0.035960
# ...         ...       ...       ...       ...       ...       ...       ...
# 17179  0.075930  0.078879  0.167305 -0.099091  0.304845  0.037762 -0.022524
# 17180 -0.072104 -0.019731 -0.014655 -0.005451 -0.005682 -0.012314  0.005986
# 17181  0.002079 -0.041786 -0.016886 -0.008919 -0.018063 -0.020858  0.006685
# 17182  0.091355 -0.055903 -0.008473 -0.017559 -0.002191 -0.013549 -0.012348
# 17183 -0.040612  0.093708 -0.039986 -0.025745 -0.032479  0.004735  0.001654
#
# ...

# %% [markdown]
# ##### 1000 dimensions

# %%
pca1000 = PCA(n_components=1000)
principalComponents1000 = pca1000.fit_transform(features)
principalDf1000 = pd.DataFrame(data = principalComponents1000)
principalDf1000
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.083198 -0.016048 -0.010595 -0.001965 -0.013778 -0.010989 -0.009680
# 1     -0.068421 -0.043649 -0.018443 -0.008228 -0.000051 -0.043176  0.127321
# 2     -0.080171 -0.044642 -0.015342 -0.008697 -0.010481 -0.057562  0.075615
# 3      0.028600 -0.040406  0.002784  0.007087  0.000463 -0.031219 -0.137444
# 4      0.255054 -0.113418 -0.019237 -0.021468 -0.040033 -0.007000 -0.035960
# ...         ...       ...       ...       ...       ...       ...       ...
# 17179  0.075930  0.078879  0.167305 -0.099091  0.304845  0.037762 -0.022525
# 17180 -0.072104 -0.019731 -0.014655 -0.005451 -0.005682 -0.012313  0.005987
# 17181  0.002079 -0.041786 -0.016886 -0.008919 -0.018063 -0.020858  0.006684
# 17182  0.091355 -0.055903 -0.008473 -0.017559 -0.002191 -0.013548 -0.012348
# 17183 -0.040612  0.093708 -0.039986 -0.025745 -0.032479  0.004734  0.001654
#
# ...

# %%
pca500 = PCA(n_components=500)
principalComponents500 = pca500.fit_transform(features)
principalDf500 = pd.DataFrame(data = principalComponents500)
principalDf500
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.083198 -0.016048 -0.010595 -0.001962 -0.013779 -0.010990 -0.009680
# 1     -0.068421 -0.043649 -0.018443 -0.008227 -0.000052 -0.043178  0.127319
# 2     -0.080170 -0.044643 -0.015340 -0.008702 -0.010482 -0.057563  0.075615
# 3      0.028600 -0.040406  0.002783  0.007087  0.000465 -0.031221 -0.137444
# 4      0.255054 -0.113418 -0.019237 -0.021470 -0.040033 -0.006997 -0.035964
# ...         ...       ...       ...       ...       ...       ...       ...
# 17179  0.075930  0.078879  0.167305 -0.099090  0.304845  0.037760 -0.022524
# 17180 -0.072104 -0.019732 -0.014654 -0.005449 -0.005684 -0.012308  0.005982
# 17181  0.002079 -0.041786 -0.016886 -0.008918 -0.018063 -0.020856  0.006686
# 17182  0.091355 -0.055903 -0.008474 -0.017555 -0.002188 -0.013549 -0.012357
# 17183 -0.040612  0.093708 -0.039985 -0.025742 -0.032475  0.004737  0.001651
#
# ...

# %% [markdown]
# ##### 200 dimensions

# %%
pca200 = PCA(n_components=200)
principalComponents200 = pca200.fit_transform(features)
principalDf200 = pd.DataFrame(data = principalComponents200)
principalDf200
# Out:
#             0         1         2         3         4         5         6    \
# 0     -0.083198 -0.016048 -0.010595 -0.001965 -0.013779 -0.010989 -0.009681
# 1     -0.068421 -0.043649 -0.018443 -0.008228 -0.000051 -0.043176  0.127322
# 2     -0.080171 -0.044642 -0.015342 -0.008697 -0.010480 -0.057562  0.075615
# 3      0.028600 -0.040406  0.002784  0.007087  0.000462 -0.031219 -0.137443
# 4      0.255054 -0.113418 -0.019237 -0.021468 -0.040033 -0.007000 -0.035960
# ...         ...       ...       ...       ...       ...       ...       ...
# 17179  0.075930  0.078879  0.167305 -0.099091  0.304845  0.037762 -0.022524
# 17180 -0.072104 -0.019731 -0.014655 -0.005451 -0.005682 -0.012314  0.005986
# 17181  0.002079 -0.041786 -0.016886 -0.008919 -0.018063 -0.020858  0.006685
# 17182  0.091355 -0.055903 -0.008473 -0.017559 -0.002191 -0.013549 -0.012348
# 17183 -0.040612  0.093708 -0.039986 -0.025745 -0.032479  0.004735  0.001654
#
# ...

# %% [markdown]
# ##### 100 dimensions

# %%
pca100 = PCA(n_components=100)
principalComponents100 = pca100.fit_transform(features)
principalDf100 = pd.DataFrame(data = principalComponents100)
principalDf100
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.083198 -0.016048 -0.010596 -0.001964 -0.013780 -0.010988 -0.009683
# 1     -0.068421 -0.043649 -0.018443 -0.008227 -0.000049 -0.043173  0.127315
# 2     -0.080171 -0.044642 -0.015342 -0.008698 -0.010480 -0.057555  0.075617
# 3      0.028601 -0.040406  0.002784  0.007088  0.000461 -0.031219 -0.137440
# 4      0.255054 -0.113418 -0.019237 -0.021466 -0.040034 -0.007000 -0.035956
# ...         ...       ...       ...       ...       ...       ...       ...
# 17179  0.075930  0.078879  0.167304 -0.099093  0.304842  0.037759 -0.022524
# 17180 -0.072104 -0.019731 -0.014655 -0.005453 -0.005680 -0.012312  0.005986
# 17181  0.002079 -0.041786 -0.016886 -0.008920 -0.018062 -0.020855  0.006686
# 17182  0.091355 -0.055903 -0.008473 -0.017561 -0.002189 -0.013553 -0.012354
# 17183 -0.040612  0.093708 -0.039985 -0.025749 -0.032473  0.004727  0.001644
#
# ...

# %%
def PCA_reduce(features,components):
    pca_n = PCA(n_components=components)
    principalComponents_N = pca_n.fit_transform(features)
    principalDf_N = pd.DataFrame(data = principalComponents_N)
    return principalDf_N

# %% [markdown]
# ## However...

# %% [markdown]
# #### There are more ways to reduce the dimensionality of a dataset

# %% [markdown]
# ##### 1. Randomized projection
# TODO

# %% [markdown]
# ##### 2. Feature Agglomeration
# TODO
